# %% [markdown]
# <a href="https://colab.research.google.com/github/fdgfranklin/laravel_firebird/blob/master/Ambienta%C3%A7%C3%A3o_EaD_e_AVA_Notebook_4_Exemplo_em_branco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Ident Visual Banner Nome Disciplina.pptx.png](data:image/png;base64,...)

# %% [markdown]
# # **Exemplo 3 - Lógica de programação e Estrutura de dados em Python - Parte II**
#
# Chegamos na nossa Semana 5. Neste Notebook iremos treinar as seguintes estruturas:
#
# * Funções
# * Biblioteca Pandas
# * Biblioteca Matplotlib
# ---
#
# Continuaremos trabalhando no exemplo do cálculo e classificação de IMC. Desta vez, utilizaremos uma base de dados pronta. Vocês devem fazer o download desta base de dados aqui: [Base de Dados IMC](https://drive.google.com/file/d/1uS_FjYbxCPs4rhx7Ats-RGTgpYWmqyoW/view?usp=sharing)

# %% [markdown]
# 1. Para trabalharmos com nossas bibliotecas, precisamos importá-las. Sendo assim, importe Pandas e Matplotlib.

# %% [markdown]
# 2. Importe a base de dados que iremos utilizar. Você deve ter feito o download dela.

# %% [markdown]
# 3. Crie uma nova coluna com o IMC de cada integrante da Base de Dados. Mostre a nova base de dados.

# %% [markdown]
# 4. Crie uma função para classificar cada integrante de acordo com seu IMC. Utilize a tabela abaixo como referência.
# * IMC < 18.5 → Abaixo do peso
# * 18.5 ≤ IMC < 25 → Peso normal
# * 25 ≤ IMC < 30 → Sobrepeso
# * IMC ≥ 30 → Obesidade

# %% [markdown]
# 5. Crie uma nova coluna no dataframe ao aplicar a função do item anterior. Mostre o novo dataframe.

# %% [markdown]
# 6. Gere um gráfico de dispersão entre as variáveis Peso e Altura.

# %% [markdown]
# **Parabéns!**
#
# Você desenvolveu nosso terceiro Notebook de exemplo!
